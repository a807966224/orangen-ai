// %%
import java.util.SplittableRandom

println("Hello, Kt Notebook!")

println("random number: ${SplittableRandom().nextDouble()}")
// Out:
// Hello, Kt Notebook!
// random number: 0.8535666769853795
